# %% [markdown]
# <a href="https://colab.research.google.com/github/Bartolomeo0609/Colab/blob/main/Josephus_exercise_Angie_Morales_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def josephus(n, skip):
    skip -= 1
    idx = skip
    while len(n) > 1:
        print n.pop(idx)
        idx = (idx + skip) % len(n)
    print 'survivor: ', n[0]



print(josephus([1,2,3,4,5,6,7,8,9], 2))
# Out:
# 2
# 4
# 6
# 8
# 1
# 5
# 9
# 7
# survivor:  3
# None

# %% [markdown]
# Se quiere encontrar la posicion en la que desea estar el historiador . Que es la posición de suicidio
#
# 1 mata a 2
# 4 mata a 5
# 6 mata a 7
# 8 mata a 1
# 4 mata a 6
